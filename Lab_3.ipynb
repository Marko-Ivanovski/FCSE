# %% [markdown]
# <a href="https://colab.research.google.com/github/jovanadobreva/Labs-I2DS/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Decision Trees and Gradient Boosting

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# For this laboratory exercise, you will need to install the Anaconda package & environment manager. We will install a minimal distribution, [Miniconda](https://docs.conda.io/projects/miniconda/en/latest/). Choose the adequate distribution for your operating system, download and install it.

# %% [markdown]
# Or use the following commands:
#
# ### Windows
# ```shell
# curl https://repo.anaconda.com/miniconda/Miniconda3-latest-Windows-x86_64.exe -o miniconda.exe
# start /wait "" miniconda.exe /S
# del miniconda.exe
# ```
#
# ### Linux
# ```shell
# mkdir -p ~/miniconda3
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm -rf ~/miniconda3/miniconda.sh
# ```
#
# ### macOS
#
# ```shell
# mkdir -p ~/miniconda3
# curl https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-arm64.sh -o ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm -rf ~/miniconda3/miniconda.sh
# ```
#
# For both Linux and macOS after installing, initialize your newly-installed Miniconda. The following commands initialize for bash and zsh shells:
#
# ```shell
# ~/miniconda3/bin/conda init bash
# ~/miniconda3/bin/conda init zsh
# ```

# %% [markdown]
# Once you have installed miniconda, run the following commands to create an environment:
# ```bash
# conda create --name myenv
# ```
#
# 'myenv' is the name of the environment, you can change the name however you want.
#
# When conda asks you to proceed, type y

# %% [markdown]
# After successfully creating the environment, activate it with the following command:
# ```bash
# conda activate myenv
# ```

# %% [markdown]
# For more detailed information you can read the [documentation](https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#creating-an-environment-with-commands).

# %% [markdown]
# Now, once the environment is activated, proceed to install the required libraries.
#
# ```bash
# pip install numpy pandas scikit-learn xgboost matplotlib seaborn gdown
# ```

# %% [markdown]
# In the next step, we need to add the environment to jupyter. Use the following commands to install ipykernel and add the environment to ipykernel.
#
# ```bash
# pip install ipykernel
# ```
# ```bash
# python -m ipykernel install --name=myenv
# ```

# %% [markdown]
# Next, start Jupyter Notebook, download this starter notebook and open it. On the dropdown menu in the Kernel tab choose the name of the environment you created, like in the picture below.

# %% [markdown]
# ![jupyter](https://drive.google.com/uc?export=view&id=1N-27jjlIgpTILi-_6lny7ng8sE52SAZx)

# %%
# !pip install numpy pandas scikit-learn xgboost matplotlib seaborn gdown
# Out:
# Collecting numpy
#   Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting xgboost
#   Downloading xgboost-2.1.3-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.9.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Downloading nvidia_nccl_cu12-2.23.4-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (164 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/lib/python3.12/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting beautifulsoup4 (from gdown)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: requests[socks] in ./miniconda3/lib/python3.12/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in ./miniconda3/lib/python3.12/site-packages (from gdown) (4.66.5)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./miniconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./miniconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 72.6 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 80.8 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 100.5 MB/s eta 0:00:00
# Downloading xgboost-2.1.3-py3-none-manylinux_2_28_x86_64.whl (153.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 46.6 MB/s eta 0:00:00
# Downloading matplotlib-3.9.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 95.2 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 83.8 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading kiwisolver-1.4.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 55.4 MB/s eta 0:00:00
# Downloading pillow-11.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 70.5 MB/s eta 0:00:00
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading scipy-1.14.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 39.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading nvidia_nccl_cu12-2.23.4-py3-none-manylinux2014_x86_64.whl (199.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.0/199.0 MB 63.8 MB/s eta 0:00:00
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, soupsieve, six, pyparsing, pillow, nvidia-nccl-cu12, numpy, kiwisolver, joblib, fonttools, filelock, cycler, scipy, python-dateutil, contourpy, beautifulsoup4, xgboost, scikit-learn, pandas, matplotlib, gdown, seaborn
# Successfully installed beautifulsoup4-4.12.3 contourpy-1.3.1 cycler-0.12.1 filelock-3.16.1 fonttools-4.55.0 gdown-5.2.0 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.9.3 numpy-2.1.3 nvidia-nccl-cu12-2.23.4 pandas-2.2.3 pillow-11.0.0 pyparsing-3.2.0 python-dateutil-2.9.0.post0 pytz-2024.2 scikit-learn-1.5.2 scipy-1.14.1 seaborn-0.13.2 six-1.16.0 soupsieve-2.6 threadpoolctl-3.5.0 tzdata-2024.2 xgboost-2.1.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## Download and Read the Dataset

# %% [markdown]
# run the code below for downloading the dataset

# %%
# !gdown 1boIax8d9Sat6OJzkiIjjpqmtSZKuRYrx
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1boIax8d9Sat6OJzkiIjjpqmtSZKuRYrx
# To: /content/ElectricCarData.csv
# 100% 8.20k/8.20k [00:00<00:00, 25.6MB/s]

# %% [markdown]
# ### Import the required libraries

# %%
import pandas as pd

# %% [markdown]
# ### Read the dataset

# %% [markdown]
# CONTEXT:
# This is a dataset of electric vehicles.
#
# It contains the following columns:
#
#
# *   Brand
# *   Model
# *   AccelSec - Acceleration as 0-100 km/h
# *   TopSpeed_KmH - The top speed in km/h
# *   Range_Km - Range in km
# *   Efficiency_WhKm - Efficiency Wh/km
# *   FastCharge_KmH - Charge km/h
# *   RapidCharge - Yes / No
# *   PowerTrain - Front, rear, or all wheel drive
# *   PlugType
# *   BodyStyle - Basic size or style
# *   Segment - Market segment
# *   Seats - Number of seats
# *   PriceEuro - Price in Germany before tax incentives

# %% [markdown]
# TASK:
# Predict the target 'PriceEuro' and compare the performance of the DecisionTreeRegressor and the XGBRegressor models.

# %%
data = pd.read_csv('/content/ElectricCarData.csv')

# %%
data.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# 1  Type 2 CCS  Hatchback       C      5      30000
# 2  Type 2 CCS   Liftback       D      5      56440
# 3  Type 2 CCS        SUV       D      5      68040
# 4  Type 2 CCS  Hatchback       B      4      32997

# %% [markdown]
# ### Encode string variables

# %%
categorical_columns = ['Brand', 'Model', 'RapidCharge', 'PowerTrain', 'PlugType', 'BodyStyle', 'Segment']

label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    label_encoders[col] = le

# %%
data.head()
# Out:
#    Brand  Model  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 0     30     46       4.6           233       450              161
# 1     31     33      10.0           160       270              167
# 2     23      0       4.7           210       400              181
# 3      2    101       6.8           180       360              206
# 4      9     78       9.5           145       170              168
#
#    FastCharge_KmH  RapidCharge  PowerTrain  PlugType  BodyStyle  Segment  \
# 0           940.0            1           0         2          7        3
# 1           250.0            1           2         2          1        2
# 2           620.0            1           0         2          2        3
# 3           560.0            1           2         2          6        3
# 4           190.0            1           2         2          1        1
#
#    Seats  PriceEuro
# 0      5      55480
# 1      5      30000
# 2      5      56440
# 3      5      68040
# 4      4      32997

# %% [markdown]
# ## Split the dataset for training and testing in ratio 80:20

# %%
X = data.drop('PriceEuro', axis=1)
y = data['PriceEuro']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Initialize the DecisionTreeRegressor model, and use the fit function for training the model.
#
# Add values for the parameters max_depth, min_samples_split, and max_features.

# %% [markdown]
# Fit the model using the fit function

# %%
dt_model = DecisionTreeRegressor(max_depth=10, min_samples_split=5, max_features='sqrt', random_state=42)

dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, max_features='sqrt', min_samples_split=5,
#                       random_state=42)

# %% [markdown]
# ## Predict the outcomes for X test

# %%
dt_predictions = dt_model.predict(X_test)

# %% [markdown]
# ## Assess the model performance, by using sklearn metrics for regression

# %%
dt_mae = mean_absolute_error(y_test, dt_predictions)
dt_mse = mean_squared_error(y_test, dt_predictions)
dt_r2 = r2_score(y_test, dt_predictions)

# %%
print(f"MAE: {dt_mae:.2f}, MSE: {dt_mse:.2f}, R^2: {dt_r2:.2f}")
# Out:
# MAE: 19760.16, MSE: 1360118148.20, R^2: -1.21

# %% [markdown]
# ## Initialize the XGBRegressor model, and use the fit function

# %% [markdown]
# Add values for the parameters: n_estimators, max_depth, learning_rate, and set the objective to "reg:squarederror"

# %% [markdown]
# Fit the model using the fit function

# %%
xgb_model = XGBRegressor(n_estimators=100, max_depth=10, learning_rate=0.1, objective='reg:squarederror', random_state=42)
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# ## Predict the outcomes for X test

# %%
xgb_predictions = xgb_model.predict(X_test)

# %% [markdown]
# ## Assess the model performance, by using sklearn metrics for regression

# %%
xgb_mae = mean_absolute_error(y_test, xgb_predictions)
xgb_mse = mean_squared_error(y_test, xgb_predictions)
xgb_r2 = r2_score(y_test, xgb_predictions)

# %%
print(f"MAE: {xgb_mae:.2f}, MSE: {xgb_mse:.2f}, R^2: {xgb_r2:.2f}")
# Out:
# MAE: 10399.45, MSE: 357692469.64, R^2: 0.42

# %% [markdown]
# ## Compare the performances of both model for at least three regression metircs

# %%
print("Model Comparison:")
print(f"{'Metric':<10} {'DecisionTree':<15} {'XGBRegressor':<15}")
print(f"{'MAE':<10} {dt_mae:<15.2f} {xgb_mae:<15.2f}")
print(f"{'MSE':<10} {dt_mse:<15.2f} {xgb_mse:<15.2f}")
print(f"{'R^2':<10} {dt_r2:<15.2f} {xgb_r2:<15.2f}")
# Out:
# Model Comparison:
# Metric     DecisionTree    XGBRegressor
# MAE        19760.16        10399.45
# MSE        1360118148.20   357692469.64
# R^2        -1.21           0.42
